# %% [markdown]
# IMPORTANDO BIBLIOTECA PANDAS

# %%
import pandas as pd #Aqui é importado a biblioteca do PANDAS para Analise

# %% [markdown]
# CARREGANDO ARQUIVOS

# %%
df2008 = pd.read_csv("DADOS.\despesa_ceaps_2008.csv", sep=";" , encoding="latin1", header=1)
df2009 = pd.read_csv("DADOS.\despesa_ceaps_2009.csv", sep=";" , encoding="latin1", header=1)
df2010 = pd.read_csv("DADOS.\despesa_ceaps_2010.csv", sep=";" , encoding="latin1", header=1)
df2011 = pd.read_csv("DADOS.\despesa_ceaps_2011.csv", sep=";" , encoding="latin1", header=1)
df2012 = pd.read_csv("DADOS.\despesa_ceaps_2012.csv", sep=";", encoding="latin1", header=1)
df2013 = pd.read_csv("DADOS.\despesa_ceaps_2013.csv", sep=";", encoding="latin1", header=1)
df2014 = pd.read_csv("DADOS.\despesa_ceaps_2014.csv", sep=";", encoding="latin1", header=1)
df2015 = pd.read_csv("DADOS.\despesa_ceaps_2015.csv", sep=";", encoding="latin1", header=1)
df2016 = pd.read_csv("DADOS.\despesa_ceaps_2016.csv", sep=";", encoding="latin1", header=1)
df2017 = pd.read_csv("DADOS.\despesa_ceaps_2017.csv", sep=";", encoding="latin1", header=1)
df2018 = pd.read_csv("DADOS.\despesa_ceaps_2018.csv", sep=";", encoding="latin1", header=1)
df2019 = pd.read_csv("DADOS.\despesa_ceaps_2019.csv", sep=";", encoding="latin1", header=1)
df2020 = pd.read_csv("DADOS.\despesa_ceaps_2020.csv", sep=";", encoding="latin1", header=1)
df2021 = pd.read_csv("DADOS.\despesa_ceaps_2021.csv", sep=";", encoding="latin1", header=1)
df2022 = pd.read_csv("DADOS.\despesa_ceaps_2022.csv", sep=";", encoding="latin1", header=1)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# <>:7: SyntaxWarning: invalid escape sequence '\d'
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# <>:9: SyntaxWarning: invalid escape sequence '\d'
# <>:10: SyntaxWarning: invalid escape sequence '\d'
# <>:11: SyntaxWarning: invalid escape sequence '\d'
# <>:12: SyntaxWarning: invalid escape sequence '\d'
# <>:13: SyntaxWarning: invalid escape sequence '\d'
# <>:14: SyntaxWarning: invalid escape sequence '\d'
# <>:15: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# ...
